# %% [markdown]
# ### Uploadind data from local machine to MongoDb

# %% [markdown]
# Loading csv dataset

# %%
import pandas as pd
import pymongo

df = pd.read_csv(r"C:\Users\Harshith N\Documents\Personal_projects\Customer-segmentation-MLOps-Pipeline\data\ecommerce_sales_analytics.csv")
df.head()
# Out:
#    order_id order_date  customer_id product_category region  quantity  \
# 0     10001   1/1/2022         1102           Beauty  South         7
# 1     10002   1/2/2022         1435         Clothing  South         7
# 2     10003   1/3/2022         1860           Beauty   East         3
# 3     10004   1/4/2022         1270      Electronics   West         5
# 4     10005   1/5/2022         1106         Clothing   West         5
#
#    unit_price  discount payment_method  delivery_days  customer_rating  \
# 0      373.65      0.28         Wallet             10              4.7
# 1       47.74      0.09           Card              6              3.9
# 2      311.28      0.31            COD              6              2.5
# 3      524.47      0.02         Wallet              6              1.6
# 4      139.87      0.33         Wallet              4              4.9
#
#    revenue
# 0  1883.20
# 1   304.10
# 2   644.35
# 3  2569.90
# 4   468.56

# %% [markdown]
# df should be converted into dict before we push it to mongodb

# %%
data = df.to_dict(orient='records')

# %%
DB_NAME = "Customer-segmentation"
COLLECTION_NAME = "Customer-segmentation-data"
CONNECTION_URL = "mongodb+srv://harshith-admin:admin1234@customer-segmentation.mw4ci7w.mongodb.net/?appName=Customer-segmentation"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
rec = collection.insert_many(data)

# %%
df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
#                         _id  order_id order_date  customer_id  \
# 0  69f4434b7db68afaf35cb1bc     10001   1/1/2022         1102
# 1  69f4434b7db68afaf35cb1bd     10002   1/2/2022         1435
#
#   product_category region  quantity  unit_price  discount payment_method  \
# 0           Beauty  South         7      373.65      0.28         Wallet
# 1         Clothing  South         7       47.74      0.09           Card
#
#    delivery_days  customer_rating  revenue
# 0             10              4.7   1883.2
# 1              6              3.9    304.1
